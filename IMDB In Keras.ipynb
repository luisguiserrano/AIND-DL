# %%
# Imports
import numpy as np
import keras
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.preprocessing.text import Tokenizer

# %%
np.random.seed(42)

# %%
# Loading the data (it's preloaded in Keras)
(x_train, y_train), (x_test, y_test) = imdb.load_data(path="imdb_full.pkl",
                                                      num_words=1000,
                                                      skip_top=0,
                                                      maxlen=None,
                                                      seed=113,
                                                      start_char=1,
                                                      oov_char=2,
                                                      index_from=3)
print(x_train.shape)
print(x_test.shape)
# Out:
# (25000,)
# (25000,)

# %%
# Turning the output into vector mode, each of length 1000
tokenizer = Tokenizer(num_words=1000)
x_train = tokenizer.sequences_to_matrix(x_train, mode='binary')
x_test = tokenizer.sequences_to_matrix(x_test, mode='binary')
print(x_train.shape)
print(x_test.shape)
# Out:
# (25000, 1000)
# (25000, 1000)

# %%
# One-hot encoding the output
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
print(y_train.shape)
print(y_train.shape)
# Out:
# (25000, 2)
# (25000, 2)

# %%
# Building the model architecture with one layer of length 100
model = Sequential()
model.add(Dense(512, input_dim=1000))
model.add(Activation('relu'))
#model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 512)               512512
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 1026
# _________________________________________________________________
# activation_6 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 513,538.0
# Trainable params: 513,538.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %%
# Running and evaluating the model
model.fit(x_train, y_train,
          batch_size=32,
          epochs=5,
          verbose=1)#,
          #validation_split=0.1)
score = model.evaluate(x_test, y_test, batch_size = 32, verbose=1)
print("")
print("")
print("accuracy: ", score[1])
# Out:
# Epoch 1/5
# 25000/25000 [==============================] - 11s - loss: 0.0873 - acc: 0.9748
# Epoch 2/5
# 25000/25000 [==============================] - 10s - loss: 0.0118 - acc: 0.9988
# Epoch 3/5
# 25000/25000 [==============================] - 10s - loss: 0.0027 - acc: 0.9999
# Epoch 4/5
# 25000/25000 [==============================] - 10s - loss: 0.0013 - acc: 1.0000
# Epoch 5/5
# 25000/25000 [==============================] - 10s - loss: 0.0010 - acc: 1.0000
# 24736/25000 [============================>.] - ETA: 0s
#
# accuracy:  0.85828
